# %% [markdown]
# # 🌸 **Iris Classification Project** 🌸
#
# Welcome to the Iris Classification Project! In this notebook, we'll explore the famous Iris dataset, visualize the data, prepare it for modeling, train a classification model, evaluate its performance, and save the model for future use. 🌟

# %% [markdown]
# ## 🧮 **Dataset Overview**
# The Iris dataset is a classic dataset in machine learning, introduced by Ronald A. Fisher in 1936. It is widely used for classification and clustering tasks due to its simplicity and clear structure. The dataset contains measurements of iris flowers and is used to classify them into different species.
#
# ### **Structure**
#
# - **Number of Samples:** 150
# - **Number of Features:** 4
# - **Number of Classes:** 3
#
# ### **Features**
#
# The dataset includes four features that describe the iris flowers:
#
# 1. **Sepal Length (cm):** The length of the sepal (outer part of the flower), measured in centimeters.
# 2. **Sepal Width (cm):** The width of the sepal, measured in centimeters.
# 3. **Petal Length (cm):** The length of the petal (inner part of the flower), measured in centimeters.
# 4. **Petal Width (cm):** The width of the petal, measured in centimeters.
#
# ### **Visualizing Features**
#
# To better understand where the sepal and other features are located on the iris flower, refer to the image below:
#
# ![Iris Flower Features](https://miro.medium.com/v2/resize:fit:1400/1*f6KbPXwksAliMIsibFyGJw.png)
# *Image Credit: Medium.com*
#
# This image visually shows the sepal length, sepal width, petal length, and petal width.
#
# ### **Classes**
#
# The dataset is divided into three classes, each representing a different species of iris flower:
#
# 1. **Iris Setosa:** Characterized by relatively shorter and wider petals and sepals.
# 2. **Iris Versicolor:** Intermediate measurements between Setosa and Virginica.
# 3. **Iris Virginica:** Generally has the largest petals and sepals among the three species.
#
# ### **Significance**
#
# - **Classification:** Used for training classification models to predict the species of iris flowers based on their measurements.
# - **Visualization:** Helpful for visualizing relationships between features and understanding the distribution of different classes.
# - **Benchmarking:** Serves as a standard benchmark for comparing various machine learning algorithms and techniques.
#
# ### **Example Data**
#
# Here’s a snapshot of what the data looks like:
#
# | Sepal Length (cm) | Sepal Width (cm) | Petal Length (cm) | Petal Width (cm) | Class        |
# |-------------------|------------------|-------------------|------------------|--------------|
# | 5.1               | 3.5              | 1.4               | 0.2              | Iris Setosa  |
# | 4.9               | 3.0              | 1.4               | 0.2              | Iris Setosa  |
# | 4.7               | 3.2              | 1.3               | 0.2              | Iris Setosa  |
# | 4.6               | 3.1              | 1.5               | 0.2              | Iris Setosa  |
# | 5.0               | 3.6              | 1.4               | 0.2              | Iris Setosa  |
# | ...               | ...              | ...               | ...              | ...          |
#
# ### **Visual Representation**
#
# For better understanding, visualizing the dataset can be quite insightful. For example, pair plots can show how features like petal length and petal width vary among the different classes.
#
# Below are images of different Iris flower classes:
#
# <table>
# <tr>
#     <td><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Irissetosa1.jpg/1280px-Irissetosa1.jpg" width="400" height="300"></td>
#     <td><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Blue_Flag%2C_Ottawa.jpg/1024px-Blue_Flag%2C_Ottawa.jpg" width="400" height="300"></td>
#     <td><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Iris_virginica_2.jpg/1024px-Iris_virginica_2.jpg" width="400" height="300"></td>
# </tr>
# <tr>
#     <td><strong>Iris Setosa</strong></td>
#     <td><strong>Iris Versicolor</strong></td>
#     <td><strong>Iris Virginica</strong></td>
# </tr>
# </table>
#
# Image Credits
# - *Iris Setosa:* [By w:ru:Денис Анисимов (talk | contribs) - Own work by the original uploader, Public Domain, https://commons.wikimedia.org/w/index.php?curid=57593826]
# - *Iris Versicolor:* [By D. Gordon E. Robertson - Own work, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=10227368]
# - *Iris Virginica:* [By Eric Hunt - Own work, CC BY-SA 4.0, https://commons.wikimedia.org/w/index.php?curid=72555262]

# %% [markdown]
# ## 📚 **Importing necessary libraries**
# In Python, libraries are collections of pre-written code that simplify complex tasks and save time. Importing libraries is essential for several reasons:
#
# 1. **Functionality:** Libraries provide a wealth of functionality that allows you to perform a wide range of tasks without having to write code from scratch. For example, libraries like `numpy` and `pandas` offer advanced data manipulation and analysis capabilities, while `matplotlib` and `seaborn` facilitate data visualization.
#
# 2. **Efficiency:** Using libraries helps streamline your code and avoid redundancy. Instead of re-implementing algorithms or functions that are already available, you can leverage these libraries to handle common tasks efficiently. This not only speeds up development but also reduces the likelihood of errors.
#
# 3. **Community and Support:** Many libraries are developed and maintained by experts in the field. By using these libraries, you benefit from the collective knowledge and best practices of the community. Additionally, popular libraries often come with extensive documentation and support, making it easier to troubleshoot issues and learn new techniques.
#
# 4. **Scalability:** Libraries are optimized for performance and can handle large datasets or complex computations efficiently. This is particularly important in machine learning and data analysis, where handling large volumes of data and performing sophisticated operations are common.
#
# 5. **Integration:** Libraries often include tools for integrating with other systems or technologies. For instance, `scikit-learn` provides interfaces for different machine learning algorithms and tools for model evaluation, while `tensorflow` and `keras` facilitate deep learning model development and deployment.

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Change directory to a folder in Google Drive
# Replace with the path to your desired folder
directory = '/content/drive/MyDrive/Colab Notebooks/Iris Flower Classification'
os.chdir(directory)

# Verify the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current working directory: /content/drive/MyDrive/Colab Notebooks/Iris Flower Classification

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import joblib

# 💡 Explanation:
# - `numpy (np)`: A fundamental package for array computing with Python. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays.
# - `pandas (pd)`: A powerful data manipulation and analysis library for Python. It provides data structures and functions needed to manipulate structured data seamlessly.
# - `seaborn (sns)`: A Python visualization library based on matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics.
# - `matplotlib.pyplot (plt)`: A plotting library for creating static, animated, and interactive visualizations in Python.
# - `sklearn.model_selection.train_test_split`: A function to split arrays or matrices into random train and test subsets. It's useful for splitting data into training and testing sets.
# - `sklearn.preprocessing.StandardScaler`: A class to standardize features by removing the mean and scaling to unit variance. Standardization of a dataset is a common requirement for many machine learning estimators.
# - `sklearn.linear_model.LogisticRegression`: A class to perform logistic regression, a type of regression analysis used for predicting binary outcomes.
# - `sklearn.metrics`: A module that implements functions assessing prediction error for specific purposes.
# - `joblib`: A library for efficiently serializing and deserializing Python objects, especially those containing large numpy arrays.

# %% [markdown]
# ##**📥 Loading the Iris dataset**
#
# ###**What is a Dataset?**
#
# A dataset is a collection of data, often presented in a tabular format, which is used for analysis or training machine learning models. Each dataset consists of multiple samples, where each sample can have several features (attributes or columns) and possibly a target variable (label or output).
#
# The Iris dataset can also be downloaded from various online repositories, such as the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/iris). The dataset is available in different formats, including CSV, JSON, and Excel, making it accessible for various tools and programming languages.
#
# ### Common Formats:
# - **CSV (Comma-Separated Values)**: A plain text format where each row corresponds to a sample and each column corresponds to a feature.
# - **JSON (JavaScript Object Notation)**: A lightweight data interchange format that is easy for humans to read and write and easy for machines to parse and generate.
# - **Excel**: A spreadsheet format commonly used for data analysis in business and academic settings.
#
# The flexibility of these formats allows you to choose the one that best fits your data processing pipeline and tools.

# %%
# 📥 Loading the Iris dataset
from sklearn.datasets import load_iris

#The help function is used to load the documentation of a function. It provides a detailed description of the function's purpose, parameters, and usage examples.
help(load_iris)
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data['target'] = iris.target
data['target'] = data['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
data.head()

# 💡 Explanation:
# - `load_iris()`: Loads the Iris dataset from sklearn's built-in datasets.
# - `pd.DataFrame()`: Converts the dataset into a pandas DataFrame, making it easier to manipulate and analyze.
# - `data['target']`: Adds a new column 'target' with the class labels.
# - `map()`: Maps the numeric target values to their corresponding class names ('setosa', 'versicolor', 'virginica').
# - `head()`: Displays the first few rows of the DataFrame.
# Out:
# Help on function load_iris in module sklearn.datasets._base:
#
# load_iris(*, return_X_y=False, as_frame=False)
#     Load and return the iris dataset (classification).
#
#     The iris dataset is a classic and very easy multi-class classification
#     dataset.
#
#     =================   ==============
#     Classes                          3
#     Samples per class               50
#     Samples total                  150
#     Dimensionality                   4
#     Features            real, positive
#     =================   ==============
#
#     Read more in the :ref:`User Guide <iris_dataset>`.
#
#     Parameters
#     ----------
#     return_X_y : bool, default=False
#         If True, returns ``(data, target)`` instead of a Bunch object. See
#         below for more information about the `data` and `target` object.
#
#         .. versionadded:: 0.18
#
#     as_frame : bool, default=False
#         If True, the data is a pandas DataFrame including columns with
# ...

# %%
# 🔍 Exploring the dataset information from the dataframe
# Display the distribution of the target classes
print("Class distribution", data['target'].value_counts())
# 💡 Explanation:
# - `value_counts()`: Counts the occurrences of each unique value in the 'target' column.

# Display the names of the features
print("Feature names:", iris.feature_names)
# 💡 Explanation:
# - `iris.feature_names`: Prints the names of the features (sepal length, sepal width, petal length, petal width).

# Display the target names
print("Target names:", iris.target_names)
# 💡 Explanation:
# - `iris.target_names`: Prints the names of the target classes (setosa, versicolor, virginica)..

# Display unique values in the target column
print("Unique target values:", data['target'].unique())
# 💡 Explanation:
# - `data['target'].unique()`: Displays unique values in the target column, showing the distinct classes in the dataset.

# Display the data types of each column
print("Data types:\n",data.dtypes)
# 💡 Explanation:
# - `data.dtypes`: Prints the data types of each column, ensuring that the data is in the expected format.
# Out:
# Class distribution target
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']
# Unique target values: ['setosa' 'versicolor' 'virginica']
# Data types:
#  sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                object
# dtype: object

# %%
# 🔍 Displaying dataset information
print("Dataset Information")
data.info()

# 🖼️ Pairplot to visualize the data
print("Pairplot")
pairplot=sns.pairplot(data, hue='target', markers=["+", "+", "+"],palette="coolwarm")
# Set the DPI of the figure
pairplot.fig.set_dpi(150)
plt.show()

# 💡 Explanation:
# - `data.info()`: Provides a concise summary of the DataFrame, including data types, non-null values, and memory usage.
# - `data.describe()`: Generates descriptive statistics that summarize the central tendency, dispersion, and shape of the dataset’s distribution, excluding NaN values.
# - `sns.pairplot()`: Creates a grid of scatter plots to visualize relationships between pairs of features in the dataset. The `hue` parameter adds color to the scatter plots based on the 'target' column, and `markers` specifies different markers for each class.
# Out:
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# Pairplot

# %% [markdown]
# ## 🌸 **Box Plot of Sepal Length by Species** 🌸
#
# A box plot is a standardized way of displaying the distribution of data based on a five-number summary: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum. For each species in the Iris dataset, the box plot of sepal length can be interpreted as follows:
#
#  **Median (Q2)**: The line inside the box represents the median sepal length, which is the middle value of the data set when it is ordered. It divides the data into two halves.
#
# **Interquartile Range (IQR)**: The box itself represents the interquartile range (IQR), which contains the middle 50% of the data. The bottom and top edges of the box are the first quartile (Q1) and the third quartile (Q3), respectively. The distance between Q1 and Q3 is known as the IQR.
#
# **Whiskers**: The lines extending from the top and bottom of the box are called whiskers. They represent the range of the data excluding outliers. The whiskers typically extend to 1.5 times the IQR from the Q1 and Q3. Any data points outside this range are considered outliers.
#
# 🔴 **Outliers**: These are individual points that fall outside the whiskers. They are usually indicated with dots or asterisks. Outliers can provide insight into variability and potential anomalies in the data.
#
# ### 📈 **Interpretation for Each Species**
#
# 🌿 **Setosa**
# - The median sepal length is relatively low compared to the other species.
# - The IQR is narrow, indicating that most of the Setosa sepal lengths are close to the median.
# - There might be a few outliers indicating some variations.
#
# 🌼 **Versicolor**
# - The median sepal length is higher than Setosa but lower than Virginica.
# - The IQR is wider than that of Setosa, suggesting more variability in sepal lengths within this species.
# - The whiskers may indicate the range extends further, showing a wider spread of data.
#
# 🌺 **Virginica**
# - The median sepal length is the highest among the three species.
# - The IQR is also wide, indicating significant variability in sepal lengths.
# - Outliers may be present, reflecting some extreme values compared to the other species.
#
# ### 💡 **General Insights**
# - Sepal lengths vary significantly between species, with Virginica having the longest and Setosa the shortest.
# - The variability (spread) of sepal lengths is also different, with Versicolor and Virginica showing more spread than Setosa.
# - Understanding these differences helps in identifying species based on sepal length and provides insights into the natural variation within and between species.

# %%
# Create a figure and axes
fig, axs = plt.subplots(1, 4, figsize=(15, 5), dpi=200)

# Define the features to plot
features = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# Plot boxplots for each feature
for ax, feature in zip(axs, features):
    sns.boxplot(x='target', y=feature, data=data, ax=ax,hue="target", palette="coolwarm")
    ax.set_title(f'Boxplot of {feature}')
    ax.set_xlabel('Species')
    ax.set_ylabel(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✂️ **Splitting the Data and Standardizing Features**
#
# In any machine learning workflow, it's crucial to split the dataset into training and testing sets. This allows us to evaluate our model's performance on unseen data, ensuring it generalizes well to new instances. Here's a step-by-step explanation of the process:
#
# 1. **Splitting the Data**
#     - We separate the features (input variables) from the target (output variable) by dropping the 'target' column from the dataset.
#     - Using the `train_test_split` function, we divide the data into training and testing sets. Typically, a split ratio of 80-20 is used, where 80% of the data is used for training the model and 20% is reserved for testing. Setting a `random_state` ensures the results are reproducible.
#
#     ![Data Splitting](https://miro.medium.com/v2/resize:fit:1400/1*NQaN71ejH_eTUxhRLwiJcA.png)
#
# 2. **Standardizing the Data**
#     - Standardization is a crucial preprocessing step, especially for algorithms that rely on distance calculations. It ensures that each feature contributes equally to the model's performance by scaling them to have a mean of 0 and a standard deviation of 1.
#     - We use the `StandardScaler` to standardize the features. The `fit_transform` method is applied to the training data to learn the scaling parameters and transform the data accordingly. The `transform` method is then applied to the test data using the same scaling parameters.
#
#     ![Standardization](https://miro.medium.com/v2/resize:fit:1358/1*7JpEYkZQzq2iIhxwNgl9Xw.png)
#
# ### Image Sources
# - Data Splitting Image: [Medium](https://medium.com/@utkarsh.kant/how-to-split-your-dataset-into-train-test-and-validation-sets-17f40e98dfd0)
# - Standardization Image: [Medium](https://medium.com/@mcbenli80/feature-scaling-5597a624afaf)

# %%
# ✂️ Splitting the data into training and testing sets
X = data.drop(columns=['target'])  # Features
y = data['target']  # Target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=29)

# 🔄 Standardizing the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 💡 Explanation:
# - `drop(columns=['target'])`: Removes the 'target' column from the DataFrame, leaving only the features.
# - `train_test_split()`: Splits the dataset into training and testing sets. `test_size=0.2` means 20% of the data is used for testing, and `random_state=42` ensures reproducibility.
# - `StandardScaler()`: Initializes the standard scaler.
# - `fit_transform()`: Fits the scaler on the training data and transforms it, standardizing the features by removing the mean and scaling to unit variance.
# - `transform()`: Transforms the testing data using the fitted scaler.

# %%
# Display shapes of the datasets
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (120, 4)
# X_test shape: (30, 4)
# y_train shape: (120,)
# y_test shape: (30,)

# %%
# Convert to DataFrame for better visualization
X_train_df = pd.DataFrame(X_train, columns=X.columns)
X_test_df = pd.DataFrame(X_test, columns=X.columns)
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X.columns)

# 🖼️ Plotting scatter plots before and after scaling for training data
# Plotting scatter plots before and after scaling for all features
fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=200)

# Scatter plot before scaling
for feature in X_train_df.columns:
    axes[0].scatter(X_train_df.index, X_train_df[feature], label=f'{feature}')
axes[0].set_title('Features Before Scaling')
axes[0].set_xlabel('Index')
axes[0].set_ylabel('Feature Value')
axes[0].legend()

# Scatter plot after scaling
for feature in X_train_scaled_df.columns:
    axes[1].scatter(X_train_scaled_df.index, X_train_scaled_df[feature], label=f'{feature}')
axes[1].set_title('Features After Scaling')
axes[1].set_xlabel('Index')
axes[1].set_ylabel('Feature Value (Scaled)')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 👀 **Key Observations**
# Here's what we can observe from the scatter plots above 👆
# - **Range Adjustment:** The primary goal of standard scaling is to adjust the ranges of the features. Before scaling, the features had vastly different ranges. After scaling, all features are on the same scale, making them comparable.
# - **Centered Data:** The scaled features are centered around 0. This can be particularly useful for many machine learning algorithms that assume the data is normally distributed around 0.
# - **Variance Normalization:** By scaling the features, we ensure that each feature contributes equally to the distance calculations in algorithms such as k-means clustering or k-nearest neighbors, preventing features with larger ranges from dominating the results.
#
# These transformations are crucial in preparing data for many machine learning models to improve their performance and convergence rates.

# %% [markdown]
# ## 🧠 **Training a Logistic Regression Model**
#
# In this section, we'll train a Logistic Regression model using our preprocessed dataset. Logistic Regression is a widely used algorithm for binary classification problems, but it can also be extended to multiclass problems like our Iris dataset. Here are the steps we'll follow:
#
# 1. **Initialize the Model:** We'll create an instance of the Logistic Regression model.
# 2. **Train the Model:** We'll fit the model to our training data.
#
# Let's dive into the process and understand the purpose behind each step:
#
# #### **Why Logistic Regression?**
#
# Logistic Regression is a simple yet powerful algorithm for classification tasks. Despite its name, Logistic Regression is used for classification, not regression. It models the probability that a given input belongs to a particular class, which is useful for binary or multiclass classification problems. Here’s how it works:
#
# 1. **Logistic Function (Sigmoid Function):** The core of Logistic Regression is the logistic function, also known as the sigmoid function. This function maps any real-valued number into the [0, 1] interval, which can be interpreted as a probability.
#
#    ![Sigmoid Function](https://upload.wikimedia.org/wikipedia/commons/8/88/Logistic-curve.svg)
#
# 2. **Decision Boundary:** Based on the probability output from the logistic function, a decision boundary is set (typically at 0.5 for binary classification) to classify the input into one of the classes.
#
# #### **Steps to Train the Model**
#
# 1. **Initialize the Model:**
#    - `LogisticRegression()`: This function creates an instance of the Logistic Regression model. At this stage, the model is ready to be trained but hasn't seen any data yet.
#
# 2. **Train the Model:**
#    - `fit()`: This method trains the model using the training data (`X_train` and `y_train`). During this step, the model learns the relationship between the input features and the target variable. Here’s what happens under the hood:
#      - **Parameter Initialization:** Initially, the model starts with random weights.
#      - **Forward Pass:** For each training example, the model computes the weighted sum of the input features and passes it through the sigmoid function to get the predicted probability.
#      - **Loss Calculation:** The model calculates the error (loss) between the predicted probabilities and the actual labels using a loss function, typically the binary cross-entropy loss.
#      - **Backpropagation:** The model computes the gradients of the loss with respect to the weights and updates the weights to minimize the loss using an optimization algorithm like Gradient Descent.
#      - **Iteration:** This process is repeated for multiple epochs (iterations) until the model converges, meaning the loss stops decreasing significantly.
#
#
# #### Benefits of Logistic Regression
# **texte en gras**
# - **Interpretable:** The coefficients of the Logistic Regression model can be interpreted to understand the influence of each feature on the target variable.
# - **Efficient:** Logistic Regression is computationally efficient and works well with small to medium-sized datasets.
# - **Probabilistic Output:** The model provides probabilities for each class, giving us more insight into the confidence of the predictions.

# %%
# 🧠 Training a Logistic Regression model
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

# Printing model details
print("Coefficients of the features:", model.coef_)
print("Intercept of the model:", model.intercept_)
print("Class labels:", model.classes_)
print("Number of iterations:", model.n_iter_)

# 💡 Explanation:
# - `LogisticRegression()`: Creates an instance of the Logistic Regression model.
# - `fit()`: Trains the model using the training data (`X_train_scaled` and `y_train_scaled`).
# - `coef_`: These represent the weights assigned to each feature. In a binary classification problem, a positive coefficient increases the log-odds of the positive class, and a negative coefficient decreases the log-odds.
# - `intercept_`: This is the bias term. It represents the log-odds of the positive class when all the features are zero.
# - `classes_`: These are the distinct class labels that the model has been trained to predict.
# - `n_iter_`: This indicates how many iterations the algorithm ran before converging to a solution.
# Out:
# Coefficients of the features: [[-1.02641149  1.18060461 -1.79967207 -1.68594452]
#  [ 0.40475704 -0.30232854 -0.14526508 -0.74858192]
#  [ 0.62165445 -0.87827608  1.94493714  2.43452644]]
# Intercept of the model: [ 0.4149742   2.00633759 -2.42131179]
# Class labels: ['setosa' 'versicolor' 'virginica']
# Number of iterations: [23]

# %% [markdown]
# ## 📈 **Making Predictions and Evaluating the Model**
#
# In this section, we will use the trained Logistic Regression model to make predictions on the test dataset. Then, we will evaluate the performance of the model using various metrics.
#
# ### **Steps Involved**
#
# 1. **Making Predictions**: We use the `predict()` method of the trained model to predict the class labels for the test data.
# 2. **Evaluating the Model**: We will assess the accuracy and generate a confusion matrix and classification report to understand the model's performance.
#
# ### **Importance of Evaluation Metrics**
#
# - **Accuracy**: Indicates the overall correctness of the model.
# - **Confusion Matrix**: Helps to identify how well the model is performing for each class.
# - **Classification Report**: Gives a comprehensive view of the model's performance, highlighting areas where the model performs well and where it needs improvement.
#
# ### **Visual Representation**
#
# Below are images that visually represent the confusion matrix and classification report, which help in understanding the performance metrics.
#
# ![Confusion Matrix Example](https://cdn.prod.website-files.com/5d7b77b063a9066d83e1209c/63b413d2cdc133446aa23fc5_636b9182cfaef2115e028921_HERO_1_Confusion.png)
# ![Classification Report Example](https://i.sstatic.net/LIWH1.jpg)
#
# *Sources for images:*
#
# - Confusion Matrix Example: [https://www.v7labs.com/blog/confusion-matrix-guide]
# - Classification Report Example: [https://datascience.stackexchange.com/questions/64441/how-to-interpret-classification-report-of-scikit-learn]

# %%
# 📈 Making predictions
y_pred = model.predict(X_test_scaled)

# 🧮 Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)

# 💡 Explanation:
# - `predict()`: Uses the trained model to make predictions on the testing data (`X_test`).
# - `accuracy_score()`: Calculates the accuracy of the model, which is the ratio of correctly predicted instances to the total instances.
# - `confusion_matrix()`: Generates the confusion matrix, which summarizes the performance of a classification algorithm.
# - `classification_report()`: Builds a text report showing the main classification metrics (precision, recall, f1-score, and support) for each class.
# Out:
# Accuracy: 0.9333333333333333
# Confusion Matrix:
# [[ 4  0  0]
#  [ 0 10  0]
#  [ 0  2 14]]
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         4
#   versicolor       0.83      1.00      0.91        10
#    virginica       1.00      0.88      0.93        16
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.96      0.95        30
# weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# ## 🗺️ **Plotting the Confusion Matrix**
#
# Visualizing the confusion matrix can help us understand the performance of our classification model in a more intuitive way. We will use a heatmap to plot the confusion matrix, which will show the true vs. predicted classifications in a clear and visually appealing manner.
#
# ### **Steps Involved**
#
# 1. **Creating the Heatmap**: We use the `sns.heatmap()` function from the Seaborn library to create a heatmap of the confusion matrix.
# 2. **Annotating the Heatmap**: We add annotations to the heatmap to display the actual values.
# 3. **Customizing the Appearance**: We format the annotations, choose a color map, and label the axes for better readability.

# %%
# 🗺️ Plotting the confusion matrix
plt.figure(dpi=200)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# 💡 Explanation:
# - `sns.heatmap()`: Creates a heatmap for the confusion matrix.
# - `annot=True`: Annotates the heatmap with the data values.
# - `fmt='d'`: Formats the annotation text as integers.
# - `cmap='Blues'`: Uses the 'Blues' colormap for the heatmap.
# - `xticklabels` and `yticklabels`: Labels the x-axis and y-axis with the target names.

# %% [markdown]
# ## ❓ **Analysis of the Confusion Matrix**
#
# The confusion matrix provides a summary of the performance of a classification model. Here's an analysis of the given confusion matrix:
#
# #### **Breakdown of the Confusion Matrix**
# - **True Positives (TP)**: The number of correct predictions for each class.
# - **False Positives (FP)**: The number of incorrect predictions where the model predicted a particular class, but the true class was different.
# - **False Negatives (FN)**: The number of incorrect predictions where the model did not predict a particular class, but the true class was that class.
#
# #### **Class-Specific Analysis**
# 1. **Setosa**
#    - **True Positives**: 4 (correctly classified as setosa)
#    - **False Positives**: 0 (none of the non-setosa instances were incorrectly classified as setosa)
#    - **False Negatives**: 0 (none of the setosa instances were misclassified)
#
# 2. **Versicolor**
#    - **True Positives**: 10 (correctly classified as versicolor)
#    - **False Positives**: 2 (virginica instances misclassified as versicolor)
#    - **False Negatives**: 0 (none of the versicolor instances were misclassified)
#
# 3. **Virginica**
#    - **True Positives**: 14 (correctly classified as virginica)
#    - **False Positives**: 0 (none of the non-virginica instances were incorrectly classified as virginica)
#    - **False Negatives**: 0 (none of the virginica instances were misclassified)
#
# #### **Overall Analysis**
# - **Accuracy**: The model correctly predicted the class of the samples 28 out of 30 times. This is a high accuracy rate.
# - **Precision and Recall**:
#   - **Precision**: The proportion of positive identifications that were actually correct. For example, precision for versicolor is 10 / (10 + 2) = 83.3%.
#   - **Recall**: The proportion of actual positives that were identified correctly. For example, recall for versicolor is 10 / 10 = 100%.
# - **Misclassification**: The only misclassification in this matrix is that 2 virginica samples were misclassified as versicolor.
#
# #### **Insights**
# - **High Accuracy**: The high number of true positives for each class indicates that the model performs well overall.
# - **No False Negatives for Setosa**: This indicates that the model can reliably identify setosa samples.
# - **Some Misclassification between Virginica and Versicolor**: There is some confusion between the virginica and versicolor classes. This could indicate that the features used for classification may have overlapping values for these two classes.

# %% [markdown]
# ## 💾 **Saving and Loading Models**
#
# Once your model is trained, saving it for future use is essential. Different methods are available for saving models, each with its unique features and use cases. Below is an overview of various methods for saving and loading models.
#
# ## 1. **Using `joblib`**
#
# `joblib` is a popular library for serializing Python objects efficiently. It is especially useful for saving scikit-learn models.
#
# - **Advantages**: Efficient for large numpy arrays and scikit-learn models.
# - **Disadvantages**: Limited to Python objects; less versatile across different libraries.
#
# ## 2. **Using `pickle`**
#
# `pickle` is a built-in Python library for serializing and deserializing Python objects. It is versatile and can handle various Python objects.
#
# - **Advantages**: Built into Python; handles most Python objects.
# - **Disadvantages**: Can be less efficient with large models; potential security risks when loading from untrusted sources.
#
#
# ## 3. **Using `MLflow`**
#
# MLflow is a platform for managing the machine learning lifecycle, including saving and loading models.
#
# - **Advantages**: Integrated with MLflow's tracking and deployment tools; supports multiple frameworks.
# - **Disadvantages**: Requires MLflow setup; may be overkill for simple use cases.
#
# ## 4. **Using `Dask`**
#
# Dask can handle scalable computing and includes options for saving models.
#
# - **Advantages**: Suitable for large-scale models; integrates with Dask's parallel computing.
# - **Disadvantages**: Less common; primarily used within Dask's ecosystem.
#
# Each method has its strengths and is suitable for different scenarios. Choose the one that best fits your needs based on the framework you are using and your model's requirements.

# %%
# Install necessary libraries
# !pip install mlflow

# %%
# 💾 Saving and Loading Models

import joblib
import pickle
import mlflow
import mlflow.sklearn


# 💾 Saving the model using joblib
# Save the model
joblib.dump(model, 'model.joblib')
# Load the model
loaded_model_joblib = joblib.load('model.joblib')
print("Model loaded with joblib:", loaded_model_joblib)

# 💾 Saving the model using pickle
# Save the model
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)
# Load the model
with open('model.pkl', 'rb') as file:
    loaded_model_pickle = pickle.load(file)
print("Model loaded with pickle:", loaded_model_pickle)

# 💾 Saving the model using MLflow
# Save the model
mlflow.sklearn.save_model(model, 'model_mlflow')
# Load the model
loaded_model_mlflow = mlflow.sklearn.load_model('model_mlflow')
print("Model loaded with MLflow:", loaded_model_mlflow)


# 💡 Explanation:
# - `joblib.dump()`: Saves the trained model to a file named 'iris_classification_model.pkl'. This allows us to reuse the model without retraining it.
# - `joblib.load()`: Loads the model from the file 'model.joblib'.
# - `pickle.dump()`: Serializes and saves the trained model to a file named 'model.pkl'.
# - `pickle.load()`: Deserializes and loads the model from the file 'model.pkl'.
# - `onnx.save_model()`: Saves the trained model in ONNX format to a file named 'model.onnx'.
# - `onnx.load()`: Loads the model from the file 'model.onnx'.
# - `mlflow.sklearn.save_model()`: Saves the trained model to a directory named 'model_mlflow'.
# - `mlflow.sklearn.load_model()`: Loads the model from the directory 'model_mlflow'.
# - `dask_ml.joblib.dump()`: Saves the trained model to a file named 'model_dask.joblib' using Dask's joblib integration.
# - `dask_ml.joblib.load()`: Loads the model from the file 'model_dask.joblib'.
# Out:
# Model loaded with joblib: LogisticRegression()
# Model loaded with pickle: LogisticRegression()
# Model loaded with MLflow: LogisticRegression()

# %%
# !cd /content/drive/MyDrive/Colab Notebooks
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /bin/bash: line 1: cd: too many arguments

# %% [markdown]
# ## **Conclusion**
#
# In this project, we explored the Iris dataset, visualized the data, prepared it for modeling, trained a Logistic Regression model, evaluated its performance, and saved the model for future use.
# Thank you for following along! 😊
